# %% [markdown]
# ## Text Mining - TP Stocks

# %% [markdown]
# ### Librerias

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline

# %%
data = pd.read_excel('C:/Users/ferna/Downloads/ypf PAGINAS.xlsx', sheet_name= 'UNIFICADO')

# %%
data
# Out:
#                                                   Text       Date  Category  \
# 0    YPF Sociedad Anónima: A Speculative Trend Play... 2023-08-04  Positive
# 1    YPF Sociedad: Q1 Earnings On Track, Production... 2023-05-14  Positive
# 2    YPF Sociedad: Shares Still A Value, Bullish Co... 2023-03-03  Positive
# 3    YPF sees continued government backing for ener... 2023-08-11  Positive
# 4    Recession fears, central bank rate hikes sent ... 2023-06-23  Negative
# ..                                                 ...        ...       ...
# 158  YPF Sociedad Anónima (NYSE:YPF) Q4 2022 Earnin... 2023-03-13  Negative
# 159  YPF Sociedad Anonima (YPF) Stock Moves -0.09%:... 2023-02-21  Negative
# 160       Best Value Stocks to Buy for February 3rd —  2023-02-03  Positive
# 161  YPF Sociedad Anonima (YPF) Moves 7.1% Higher: ... 2023-01-16  Positive
# 162  The Top 5 Exploration Prospects of 2023 — 2022... 2023-01-06  Positive
#
#     Train/Test                                             Pagina
# 0         Test                               www.seekingalpha.com
# 1        Train                               www.seekingalpha.com
# 2        Train                               www.seekingalpha.com
# 3         Test                               www.seekingalpha.com
# 4        Train                               www.seekingalpha.com
# ..         ...                                                ...
# 158      Train  https://finance.yahoo.com/news/ypf-sociedad-ni...
# 159      Train  https://finance.yahoo.com/news/ypf-sociedad-an...
# 160      Train  https://finance.yahoo.com/news/best-value-stoc...
# 161      Train  https://finance.yahoo.com/news/ypf-sociedad-an...
# 162      Train  https://oilprice.com/Energy/Crude-Oil/The-Top-...
#
# [163 rows x 5 columns]

# %% [markdown]
# ### Train / Test

# %%
data_train = data[data['Train/Test'].isin(['Train'])]
data_test = data[data['Train/Test'].isin(['Test'])]

# %%
X_train = data_train['Text'].tolist()
y_train = data_train['Category'].tolist()

# %%
X_test = data_test['Text'].tolist()
y_test = data_test['Category'].tolist()

# %%
# Stemming / Lemma / stopwords
# clf: logistica / SVM / Random Forest //// BERT

text_clf = Pipeline([('vect' , CountVectorizer()), 
                     ('tfidf', TfidfTransformer()), 
                     ('clf'  , MultinomialNB())
                    ])

# %% [markdown]
# ### Entrenamiento

# %%
text_clf = text_clf.fit(X_train, y_train)

# %% [markdown]
# ### Testeo

# %%
X_train[2]
# Out:
# 'Recession fears, central bank rate hikes sent crude oil reeling this week'

# %%
predicted = text_clf.predict(['Argentina Fixes Oil at $56 a Barrel to Put Lid on Inflation'])

# %%
predicted
# Out:
# array(['Positive'], dtype='<U8')

# %%
data_train
# Out:
#                                                   Text       Date  Category  \
# 1    YPF Sociedad: Q1 Earnings On Track, Production... 2023-05-14  Positive
# 2    YPF Sociedad: Shares Still A Value, Bullish Co... 2023-03-03  Positive
# 108      YPF Upcoming Earnings Report: What to Expect? 2023-08-08   Neutral
# 109  Mexico's Pemex the biggest liquidity worry amo... 2023-08-23   Neutral
# 110  Argentina to freeze crude price at $56/bbl to ... 2023-08-18  Negative
# 111  YPF expects Argentina to maintain support for ... 2023-08-11  Positive
# 112  Key pipeline needs investment to deliver Argen... 2023-07-26  Positive
# 129  Vaca Muerta's Sweet Crude Attracts Global Ener... 2023-08-24  Positive
# 130  YPF Sociedad Anonima (YPF) Outpaces Stock Mark... 2023-07-21   Neutral
# 131      14 Best Multibagger Stocks to Buy for 2024 —  2023-07-11  Positive
# 132  YPF Sociedad Anonima (YPF) Gains As Market Dip... 2023-07-05   Neutral
# 133  Will Argentina Reach Its 1 Million Bpd Oil Pro... 2023-07-01  Positive
#
#     Train/Test                                             Pagina
# 0         Test                               www.seekingalpha.com
# 3         Test                               www.seekingalpha.com
# 17        Test                                 google.com/finance
# 18        Test  https://www.marketscreener.com/quote/stock/YPF...
# 19        Test         https://www.bloomberg.com/search?query=YPF
# 20        Test         https://www.bloomberg.com/search?query=YPF
# 21        Test         https://www.bloomberg.com/search?query=YPF
# 22        Test         https://www.bloomberg.com/search?query=YPF
# 23        Test         https://www.bloomberg.com/search?query=YPF
# 24        Test         https://www.bloomberg.com/search?query=YPF
# 25        Test         https://www.bloomberg.com/search?query=YPF
# 26        Test         https://www.bloomberg.com/search?query=YPF
# 27        Test         https://www.bloomberg.com/search?query=YPF
# 39        Test     https://www.ft.com/search?sort=relevance&q=YPF
# 42        Test     https://www.ft.com/search?sort=relevance&q=YPF
# 43        Test     https://www.ft.com/search?sort=relevance&q=YPF
# 45        Test  https://www.zacks.com/stock/research/YPF/all-n...
# 46        Test  https://www.zacks.com/stock/research/YPF/all-n...
# 50        Test  https://www.zacks.com/stock/research/YPF/all-n...
# 107       Test           https://www.cnbc.com/quotes/YPF?tab=news
# 108       Test           https://www.cnbc.com/quotes/YPF?tab=news
# 109       Test     https://www.reuters.com/site-search/?query=YPF
# 110       Test     https://www.reuters.com/site-search/?query=YPF
# 111       Test     https://www.reuters.com/site-search/?query=YPF
# 112       Test     https://www.reuters.com/site-search/?query=YPF
# 129       Test  https://oilprice.com/Energy/Crude-Oil/Vaca-Mue...
# 130       Test  https://finance.yahoo.com/news/ypf-sociedad-an...
# 131       Test  https://finance.yahoo.com/news/14-best-multiba...
# 132       Test  https://finance.yahoo.com/news/ypf-sociedad-an...
# 133       Test  https://oilprice.com/Energy/Crude-Oil/Will-Arg...

# %%
predicted
# Out:
# array(['Positive', 'Positive', 'Positive', 'Positive', 'Positive',
#        'Positive', 'Positive', 'Positive', 'Positive', 'Positive',
#        'Positive', 'Positive', 'Positive', 'Positive', 'Positive',
#        'Positive', 'Positive', 'Positive', 'Positive', 'Positive',
#        'Positive', 'Positive', 'Positive', 'Positive', 'Positive',
#        'Positive', 'Positive', 'Positive', 'Positive', 'Positive'],
#       dtype='<U8')

# %% [markdown]
# ## TODO
# ### 1. Clasificar data 2021 y 2022
# ### 2. Reclasificar NEUTRO -> NEGATIVO
# ### 3. Lemma, stopwords
#
# ### 4. Aplicar otros metodos de clasificacion: logistica / SVM / Random Forest //// BERT (NN)
