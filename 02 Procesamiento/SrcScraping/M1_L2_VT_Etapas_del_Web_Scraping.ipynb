# %% [markdown]
# # Etapas del Web Scraping

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://www.yahoo.com'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.request.headers
# Out:
# {'User-Agent': 'python-requests/2.24.0', 'Accept-Encoding': 'gzip, deflate', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html id="atomic" lang="es-US" class="atomic   l-out Pos-r https fp fp-v2 rc1 fp-default mini-uh-on uh-topbar-on viewer-right two-col ntk-wide ltr desktop Desktop bkt726">\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    \n    <title>Yahoo</title><meta http-equiv="x-dns-prefetch-control" content="on"><link rel="dns-prefetch" href="//s.yimg.com"><link rel="preconnect" href="//s.yimg.com"><link rel="dns-prefetch" href="//csc.beap.bc.yahoo.com"><link rel="preconnect" href="//csc.beap.bc.yahoo.com"><link rel="dns-prefetch" href="//geo.yahoo.com"><link rel="preconnect" href="//geo.yahoo.com"><link rel="dns-prefetch" href="//comet.yahoo.com"><link rel="preconnect" href="//comet.yahoo.com"><link rel="dns-prefetch" href="//video-api.yql.yahoo.com"><link rel="preconnect" href="//video-api.yql.yahoo.com">    <meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n    \n    <meta name="description" content="Las noticias, el correo electrónic
# ...

# %%
#!conda install -c anaconda beautifulsoup4 -y

# %%
page = BeautifulSoup(response.text, 'html.parser')

# %%
page.title
# Out:
# <title>Yahoo</title>

# %%
page.title.string
# Out:
# 'Yahoo'

# %%
page.find_all('h1')
# Out:
# [<h1 class="Fz(0) Pstart(15px) Pos(a)"><a class="D(b) Pos(r)" data-ylk="elm:img;elmt:logo;sec:hd;slk:logo" href="https://espanol.yahoo.com/" id="header-logo"><img alt="Yahoo" class="H(27px)!--sm1024 Mt(9px)!--sm1024 W(90px)!--sm1024" height="58px" src="https://s.yimg.com/rz/p/yahoo_frontpage_en-US_s_f_p_205x58_frontpage_2x.png" title="Yahoo" width="205px"/></a></h1>]

# %%
form = page.find('form')

# %%
form
# Out:
# <form action="https://espanol.search.yahoo.com/search" class="D(tb) H(46px) Pos(r) Va(m) W(100%)" data-ylk="elm:kb-ent;elmt:srch;sec:srch;slk:srchweb;tar:espanol.search.yahoo.com" id="header-search-form" method="get" target="_top"><label class="Hidden" for="header-search-input">Buscar</label><input aria-autocomplete="list" aria-expanded="false" aria-label="" autocapitalize="off" autocomplete="off" class="Bgc(t) Bd Bdrsbstart(2px)! Bdc(#b0b0b0) Bdendw(0) Bdrs(0) Bdrststart(2px)! Bxsh(n) Bxz(bb) D(b) Fz(18px) H(inh) M(0) O(0) Px(10px) W(100%) Bdc($c-fuji-blue-1-c):f Bdc(#949494):h" id="header-search-input" name="p" placeholder="" type="text"/><div class="D(tbc) H(100%) Ta(c) Va(t) W(90px)"><button aria-label="Buscar" class="Bgc(#5701ed) submit-btn Bd(n) Bdrsbend(2px) Bdrstend(2px) D(b) H(100%) M(0) P(0) rapid-noclick-resp W(100%)" data-ylk="elm:btn;elmt:srch;itc:0;rspns:nav;sec:srch;slk:srchweb;t1:a1;t2:srch;tar:espanol.search.yahoo.com;tar_uri:/search" id="header-desktop-search-button
# ...

# %%
import urllib.request

# %%
urllib.request.urlretrieve('https://yahoo.com/robots.txt',"c:/scraping/yahoorobots.txt")
# Out:
# ('c:/scraping/yahoorobots.txt', <http.client.HTTPMessage at 0x268eebaac70>)

# %%
link="http://www.yahoo.com/sitemap.xml"

# %%
content = requests.get(link).text

# %%
content
# Out:
# '<html>\n<meta charset=\'utf-8\'>\n<script>\nvar u=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2fwww.yahoo.com%2fsitemap.xml\';\nif(window!=window.top){\n  document.write(\'<p>Content is currently unavailable.</p><img src="//geo.yahoo.com/p?s=1197757039&t=\'+new Date().getTime()+\'&_R=\'+encodeURIComponent(document.referrer)+\'&err=404&err_url=\'+u+\'" width="0px" height="0px"/>\');\n}else{\n  window.location.replace(u);\n}\n</script>\n<noscript><META http-equiv="refresh" content="0;URL=\'https://www.yahoo.com/?err=404&err_url=https%3a%2f%2fwww.yahoo.com%2fsitemap.xml\'"></noscript>\n</html>\n'

# %%
r = urllib.request.urlopen('http://www.yahoo.com')
print(r.getheader('Content-Type'))
print(r.getheader('Expires'))
# Out:
# text/html; charset=UTF-8
# -1

# %% [markdown]
# ____________________
